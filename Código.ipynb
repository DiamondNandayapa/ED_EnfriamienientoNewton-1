# %% [markdown]
# # Proyecto Módulo 3 Ecuaciones diferenciales
#  ### Diamante del cielo Gutiérrez Nandayapa
#  ### Isaura Rodríguez Navarro

# %% [markdown]
# # Ley de enfriamineto de Newton
# \begin{equation}
# \frac{dT}{dt} = {k}(T-T_A)
# \end{equation}
# Solución analítica de la ecuación con sympy

# %%
import sympy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import *

# %%
sym.var('t') 
sym.var('k')
sym.var('Ta')
T=sym.Function('T')
eq=sym.Derivative(T(t),t)-k*(T(t)-Ta) 
solucion=sym.dsolve(eq,T(t))
solucion
# Out:
# Eq(T(t), C1*exp(k*t) + Ta)

# %% [markdown]
# Temperatura del ambiente es 30, $T_A$=30°C
# Las condiciones son T(0)=80°C

# %%
sym.var('t') 
sym.var('k')
T=sym.Function('T')
eq=sym.Derivative(T(t),t)-k*(T(t)-30) 
solucion1=sym.dsolve(eq,T(t))
solucion1
# Out:
# Eq(T(t), C1*exp(k*t) + 30)

# %% [markdown]
# Se determina $C_1$ con las condiciones iniciales

# %%
solucion1.subs('C1',50)
# Out:
# Eq(T(t), 50*exp(k*t) + 30)

# %% [markdown]
# Para cualquier valor de $C_1$ teniendo condiciones inicales en tiempo 0

# %%
def funcionC(TA,T0):
    return T0-TA
funcionC(100,180)
# Out:
# 80

# %%
C1=funcionC(100,180)
C1
# Out:
# 80

# %% [markdown]
# C1 para cualquier tiempo

# %%
# Definimos el sistema de ecuaciones
def f(xyz, t, sigma, rho, beta):
    x, y, z = xyz
    return [sigma * (y - x), 
           x * (rho - z) - y,
           x * y - beta * z]

# Asignamos valores a los parámetros
sigma, rho, beta = 8, 28, 8/3.0

# Condición inicial y valores de t sobre los que calcular
xyz0 = [1.0, 1.0, 1.0]
t = np.linspace(0, 25, 10000)

# Resolvemos las ecuaciones
xyz1 = integrate.odeint(f, xyz0, t, args=(sigma, rho, beta))
xyz2 = integrate.odeint(f, xyz0, t, args=(sigma, rho, 0.6*beta))
xyz3 = integrate.odeint(f, xyz0, t, args=(2*sigma, rho, 0.6*beta))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3892182e45fe> in <module>
#      14
#      15 # Resolvemos las ecuaciones
# ---> 16 xyz1 = integrate.odeint(f, xyz0, t, args=(sigma, rho, beta))
#      17 xyz2 = integrate.odeint(f, xyz0, t, args=(sigma, rho, 0.6*beta))
#      18 xyz3 = integrate.odeint(f, xyz0, t, args=(2*sigma, rho, 0.6*beta))
#
# NameError: name 'integrate' is not defined

# %%
# Graficamos las soluciones
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig, (ax1,ax2,ax3) = plt.subplots(1, 3, figsize=(12, 4),
                                  subplot_kw={'projection':'3d'})

for ax, xyz, c in [(ax1, xyz1, 'r'), (ax2, xyz2, 'b'), (ax3, xyz3, 'g')]:
    ax.plot(xyz[:,0], xyz[:,1], xyz[:,2], c, alpha=0.5)
    ax.set_xlabel('$x$', fontsize=16)
    ax.set_ylabel('$y$', fontsize=16)
    ax.set_zlabel('$z$', fontsize=16)
    ax.set_xticks([-15, 0, 15])
    ax.set_yticks([-20, 0, 20])
    ax.set_zticks([0, 20, 40])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d1ca2b8d9952> in <module>
#       4                                   subplot_kw={'projection':'3d'})
#       5
# ----> 6 for ax, xyz, c in [(ax1, xyz1, 'r'), (ax2, xyz2, 'b'), (ax3, xyz3, 'g')]:
#       7     ax.plot(xyz[:,0], xyz[:,1], xyz[:,2], c, alpha=0.5)
#       8     ax.set_xlabel('$x$', fontsize=16)
#
# NameError: name 'xyz1' is not defined
